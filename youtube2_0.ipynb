# %% [markdown]
# <a href="https://colab.research.google.com/github/knitemblazor/scrapping-youtube-comments-for-sentiments-analysis/blob/master/youtube2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install autocorrect
import nltk
# Out:
# Requirement already satisfied: autocorrect in /usr/local/lib/python3.6/dist-packages (0.3.0)

# %%
from textblob import TextBlob

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
file = open('/content/gdrive/My Drive/comments_analysis/comments.txt',"r") #comments of  delhi video tours  especially food related
comments= file.read().splitlines()  
print(len(comments),"of comments in the given dataset")
file.close()
# Out:
# 874932 of comments in the given dataset

# %%
from pprint import pprint
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktTrainer
from autocorrect import spell
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer


class sentimenttagger(object):
  
  def __init__(self,sentences):
    self.sentences=sentences
  
  def textfinetuner(self):
    trainer = PunktTrainer()
    trainer.INCLUDE_ALL_COLLOCS = True
    trainer.train(self.sentences)
    tokenizer = PunktSentenceTokenizer(trainer.get_params())
    sense=tokenizer.tokenize(self.sentences)
    res = []
    sentence=[]
    for text in textList:
      new_text = ''.join(c for c in text if c not in string.punctuation)
      res.append(new_text)
    with open('/content/gdrive/My Drive/comments_analysis/commentsnew.txt', 'w') as f:
       for sent in res:
          sent=' '.join((spell(str(word))) for word in sent.split())
          f.write("%s\n" % sent)
          sentence.append(sent)
    file.close()
    self.sentence=sentence
    return sentence
  

  def sentianalyzer(self):
      label=[]
      for i in range(len(self.sentence)):
        blob = TextBlob(str(self.sentence[i]), analyzer=NaiveBayesAnalyzer())
        q=blob.sentiment
        label.append(1 if str(q[0])=="pos" else 0)
      with open('/content/gdrive/My Drive/comments_analysis/label.txt', 'w') as f:
        for item in label:
            f.write("%s\n" % item)
      file.close()
      return label
    
obj = sentimenttagger(comments[:3])
text =obj.textfinetuner()
sent = obj.sentianalyzer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-9dd0b650ef51> in <module>()
#      45
#      46 obj = sentimenttagger(comments[:3])
# ---> 47 text =obj.textfinetuner()
#      48 sent = obj.sentianalyzer()
#
# <ipython-input-162-9dd0b650ef51> in textfinetuner(self)
#      14     trainer = PunktTrainer()
#      15     trainer.INCLUDE_ALL_COLLOCS = True
# ---> 16     trainer.train(self.sentences)
#      17     tokenizer = PunktSentenceTokenizer(trainer.get_params())
#      18     sense=tokenizer.tokenize(self.sentences)
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in train(self, text, verbose, finalize)
#     715         # Break the text into tokens; record which token indices correspond to
#     716         # line starts and paragraph starts; and determine their types.
# --> 717         self._train_tokens(self._tokenize_words(text), verbose)
#     718         if finalize:
#     719             self.finalize_training(verbose)
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in _train_tokens(self, tokens, verbose)
#     731
#     732         # Ensure tokens are a list
# --> 733         tokens = list(tokens)
#     734
#     735         # Find the frequency of each case-normalized type.  (Don't
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in _tokenize_words(self, plaintext)
#     544         """
#     545         parastart = False
# --> 546         for line in plaintext.split('\n'):
#     547             if line.strip():
#     548                 line_toks = iter(self._lang_vars.word_tokenize(line))
#
# AttributeError: 'list' object has no attribute 'split'

# %%
print(text[2],len((comments)))
# Out:
# House part really eye opening This is the exact experience I want to have in India 22318

# %%
file = open('/content/gdrive/My Drive/comments_analysis/comments.txt',"r") #comments of  delhi video tours  especially food related
comments= file.read().splitlines()  
print(len(comments),"of comments in the given dataset")
file.close()

 

filename = '/content/gdrive/My Drive/latest/negative.txt'
file = open(filename,"r" )
negative = file.read().splitlines()
file.close()   

filename = '/content/gdrive/My Drive/latest/positive.txt'
file = open(filename,"r" )
positive = file.read().splitlines()
file.close()

lab=[]
for i in range(len(comments)):
    lab.append(0)
def label(comments,negative,positive):
    for i in range(len(comments)):
        words=comments[i].split()
        for j in range(len(words)):
            for k in range(len(positive)):
                if(words[j]==positive[k]):
                    lab[i]=1
                
            for l in range(len(negative)): 
                if(words[j]==negative[l]):
                    lab[i]=2
                
           
# label(comments,negative,positive)    
# print(lab)
# Out:
# 22318 of comments in the given dataset
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-141-0bfff58b7bc4> in <module>()
#       8
#       9 filename = '/content/gdrive/My Drive/latest/negative.txt'
# ---> 10 file = open(filename,"r" )
#      11 negative = file.read().splitlines()
#      12 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/latest/negative.txt'

# %%
filename = '/content/gdrive/My Drive/latest/stopwords.txt'
file = open(filename,"r" )
stopwords = file.read().splitlines()
file.close() 
d=comments
words=[]
sentences =[]
k = []
for i in range(len(d)):
    sentences.append(0)
for i in range(0,len(d)):
    sentences[i]=d[i].split()
    for j in sentences[i]:   
        if(len(j)<9):         #part of filtering
            words.append(j)
wordsf= []
words = [word.lower() for word in words]
words = [word for word in words if word.isalpha()]# setting the vocabulary
wordsf=(set(words).difference(stopwords))      
 
print(len(words))
words=list(wordsf)
print(len(sentences))
# Out:
# 338342
# 30080

# %%
j=[]
sentencesf=[]         #calculating the length of all sentences ie the no. of words
labelf=[]
for i in range(len(sentences)):
  j.append(len(sentences[i]))
  
for i in range(len(j)):
  if(j[i]<=28):
    sentencesf.append(sentences[i])
    labelf.append(lab[i])
with open('/content/gdrive/My Drive/latest/sentencesf.txt', 'w') as f:
    for item in sentencesf:
        f.write("%s\n" % item)
file.close()

with open('/content/gdrive/My Drive/latest/labelf.txt', 'w') as f:
    for item in labelf:
        f.write("%s\n" % item)
file.close()
print(len(sentencesf),len(labelf))
# Out:
# 27263 27263

# %%
import numpy as np
from gensim.models import Word2Vec


# define training data
# print((comments[5]))
# train model
# filename='/content/gdrive/My Drive/latest/sentencesf.txt'
# file = open(filename,"r" )
# sentencesf= file.read().splitlines()
# file.close()
model = Word2Vec(sentencesf,size=28, min_count=1)#word vector dim=28
# summarize the loaded model
print(model)
# summarize vocabulary
words = list(model.wv.vocab)
print(words)
# access vector for one word
print(model[ 'was' ])
# save model

zerovector=[]
for i in range(28):
  zerovector.append(0)

filename='/content/gdrive/My Drive/latest/labelf.txt'
file = open(filename,"r" )
labelf= file.read().splitlines()
file.close()



# print(label)

def sentencevector(sent):
  vector=[]
  for word in sent:
       vector.append(model[word])
  if(len(sent)<28):
    for i in range(len(sent),28):
      vector.append(zerovector)
  return(vector)

Xtotal=[]
Ytotal=labelf
for i in range(len(sentencesf)):
  a=np.array(sentencevector(sentencesf[i]))
  Xtotal.append(a)
# Out:
# Word2Vec(vocab=36571, size=28, alpha=0.025)
# ['That', 'was', 'the', 'best', 'brain', 'I', 've', 'ever', 'had', 'you', 'should', 'try', 'coming', 'to', 'Tunisia', 'When', 'will', 'u', 'come', 'pakistan?', 'Nice', 'English', 'skill', 'by', 'kasouri', 'wala', 'This', 'is', 'so', 'sad', "didn't", 'test', 'biryani', 'All', 'of', 'video', 'in', 'India,', 'why', 'all', 'sellers', 'are', 'men?', 'like', 'how', 'fit', 'wherever', 'go,', 'one', 'reviews', 'have', 'seen', 'Stuffed', 'nun', '500rs,', 'they', 'fooled', 'you.', 'King', 'unhygenic', 'food', 'land.', 'Please', 'comes', 'Bangladesh', 'Superb', '.......subscribe', 'me........', 'Too', 'much', 'spicy', '=Ass', 'Burn', 'spices', 'indian', 'food,', 'would', 'go', 'india', 'just', 'for', 'foods', 'Do', 'a', 'trip', 'El', 'Salvador', 'street', 'Come', 'bakani', 'Paratha', 'wali', 'gaali.', 'am', 'from', 'Pakistan', 'and', 'we', 'also', 'love', 'India', 'watching', 'taste', 'Indians', 'live', 'pigs', 'Welcome', 'India....', 'had.', 'visit', 'North', 'East', 'India.', 'It', 's', 'totally', 'different', 'other', 'cities', 'hope', 'll', 'it.', "don't", 'think', 'deep', 'fry', 'parantha?', 'want.', '...', 'Very', 'nice', 'Supar', 'pak', 'Ilike', 'too', 'this', 'program', 'very', 'cool', 'Hahahah', 'charge', '3', 'times', 'more', 'every', 'time', 'RIP', 'his', 'butt', 'Honestly', 'segments', 'on', 'youtube!', 'Others', 'cannot', 'compete!', 'Keep', 'up', 'good', 'work!', 'Hey', 'man,', 'manek', 'chauk,', 'Ahmedabad,', 'Gujarat,', 'There', 'variety', 'dishes..visit', 'ahmedabad', 'Why', 'no', 'places', 'usa', 'went', 'there.', 'Prices', 'shown', 'exactly', 'what', 'everyone.', 'Tourist', 'or', 'not.', 'Loved', 'place', "It's", 'see', 'that', 'most', 'vendors', 'using', 'disposal', 'cutlery', 'ensuring', 'hygiene', 'i', 'hygene', 'hell', 'shits', 'lol', 'watch', '.........love', 'Ur', 'videos......keep', 'making', 'more......whenever', 'Delhi,', 'welcome', 'my', 'house', 'feast.......', 'Aaa', 'yyyy', 'eeee', 'vvooo', 'ihhh', 'Fried', 'stuffed', 'with', 'butter', 'No', 'wonder', 'Indian', 'people', 'get', 'heart', 'attacks', 'at', '35', 'If', 'japan', 'check', 'foodie', 'experience', ',', 'it', 'awesome', 'www.washokuclub.com', 'You', 'Speak', 'hindi', 'Chinese', 'Accent', 'Some', 'unfriendly', 'Trevor', 'nicest', 'humble', 'man!', 'God', 'gifted', 'metabolic', 'system', 'Did', 'ur', 'women', 'partner', 'been', 'raped', 'dog', 'cum', 'shot', 'inside?', 'not', 'refried', 'beans', 'Honk', 'honk', 'hoooooooooonnnnkkkkkk', 'hoooonnnk', '...honk..honk', '.honk...hoooooonnnnkkkkkk', 'honnnnkkkk', 'hooooooonkkkkk', '...honk', 'hhhhhooooonnnnk', '..', 'omg', '7:06', 'run', 'your', 'life', 'xD', 'make', 'me', 'hungry', 'hahaa', 'Hi', 'Trevor,', 'some', 'restaurants', 'too.', 'And', 'missed', 'famous', 'Nihari', 'dish.', 'nah', 'NANNMAN!!!!!!!!.like', 'Batman', 'but', 'NAANMAN', 'The', 'looks', 'delicious', 'got', 'eyeache', 'city', 'Bro', 'please', 'dal', 'makni', 'Paani', 'puri', 'scammed', 'kachori', '10', 'ki', 'Ohhhhh....thank', 'you!!!', 'pakistan', 'must', 'Lahore,', 'delighted', 'eat', 'Gujarati', "it's", 'fab', 'selfish', 'arrogant', 'poor', 'respectful', 'rich', 'evil', 'matter', 'treat', 'dogs', "they'll", 'never', 'stop', 'barking.', 'can', 'god', 'there', '25', 'bucks', 'week', 'r', 'Delhi', 'dont', 'call', 'pani', 'Gol', 'gappe', 'Good', 'video.', 'Oh', 'oil', 'take', 'easy', 'Are', 'winter', 'bet', 'an', 'upset', 'stomach', 'next', 'day', '!!!', ':)::)', '@9:52', '-', "that's", 'she', 'said.', 'Pakistani', 'Rehan', 'Aslam', '................isko', 'marna', 'nahi', 'hain', 'BOMB', 'BLAST', 'main.............', 'Awwww', "you're", 'cute', 'Nan', 'surely', 'makes', 'Zomato', 'add', 'beginning', 'ordered', 'if', 'these', 'were', 'sold', 'Canada', 'US,', 'cost', 'plate?', '<3', 'used', 'neaby,', 'chandni', 'chawk', 'paradise', 'many', 'sweet', 'snack', 'shops', 'jung', 'bahadur', 'love,', 'parathe', 'overrated', 'id', 'along', 'anywhere', 'africa', 'sorry', 'help', 'now', 'USA', 'Naa', 'ke', 'bas', "Kutch's", 'til', 'naan', 'rogni', 'w ...
# [ 3.1279435  -2.4638484   1.0987207  -2.5427027   0.36895412  1.27334
#  -1.1621435   0.87405264 -0.44771007  3.3231008   1.7373496  -0.76687986
#   1.0479159   0.16235118 -3.1547441   2.2406468  -0.8726848   0.18117334
#   1.6386044   0.48264262 -0.8096907  -2.5237997   0.394601   -3.801136
#   0.04163094 -0.17305622 -4.5401998  -2.7628536 ]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
import tensorflow as tf

Xtrain=np.array(Xtotal[:20000])
Xtest=np.array(Xtotal[20000:27263])
Y_train=np.array(Ytotal[:20000])
Y_test=np.array(Ytotal[20000:27263])
X_train = Xtrain.reshape(Xtrain.shape[0], 28, 28 , 1).astype('float32')
X_test=Xtest.reshape(Xtest.shape[0], 28, 28 , 1).astype('float32')

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(100, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(50, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(3, activation=tf.nn.softmax)
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, Y_train, epochs=10)
model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/10
# 20000/20000 [==============================] - 4s 215us/step - loss: 0.8506 - acc: 0.6190
# Epoch 2/10
# 20000/20000 [==============================] - 2s 112us/step - loss: 0.8012 - acc: 0.6348
# Epoch 3/10
# 20000/20000 [==============================] - 2s 110us/step - loss: 0.7825 - acc: 0.6470
# Epoch 4/10
# 20000/20000 [==============================] - 2s 109us/step - loss: 0.7685 - acc: 0.6556
# Epoch 5/10
# 20000/20000 [==============================] - 2s 108us/step - loss: 0.7542 - acc: 0.6629
# Epoch 6/10
# 20000/20000 [==============================] - 2s 104us/step - loss: 0.7444 - acc: 0.6713
# Epoch 7/10
# 20000/20000 [==============================] - 2s 111us/step - loss: 0.7290 - acc: 0.6769
# Epoch 8/10
# 20000/20000 [==============================] - 2s 114us/step - loss: 0.7185 - acc: 0.6857
# Epoch 9/10
# 20000/20000 [==============================] - 2s 109us/step - loss: 0.7039 - acc: 0.6943
# Epoch 10/10
# 20000/20000 [==============================] - 2s 102us/step - loss: 0.6900 - acc: 0.6986
# 7263/7263 [==============================] - 1s 158us/step
# [0.7658563222780743, 0.6732755058825747]

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

Xtrain=np.array(Xtotal[:15000])
Xtest=np.array(Xtotal[15000:27263])
Y_train=np.array(Ytotal[:15000])
Y_test=np.array(Ytotal[15000:27263])
X_train = Xtrain.reshape(Xtrain.shape[0], 28, 28 , 1).astype('float32')
X_test=Xtest.reshape(Xtest.shape[0], 28, 28 , 1).astype('float32')

model = Sequential()
model.add(Conv2D(200, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(28,28,1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer='adam',
              metrics=['accuracy'])

model.fit(X_train, Y_train,
          batch_size=40,
          epochs=5,
          
          validation_data=(X_test, Y_test))
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 15000 samples, validate on 12263 samples
# Epoch 1/5
# 15000/15000 [==============================] - 239s 16ms/step - loss: 6.3904e-08 - acc: 0.2759 - val_loss: 6.7620e-08 - val_acc: 0.2937
# Epoch 2/5
# 15000/15000 [==============================] - 234s 16ms/step - loss: 6.3904e-08 - acc: 0.2759 - val_loss: 6.7620e-08 - val_acc: 0.2937
# Epoch 3/5
# 15000/15000 [==============================] - 235s 16ms/step - loss: 6.3904e-08 - acc: 0.2759 - val_loss: 6.7620e-08 - val_acc: 0.2937
# Epoch 4/5
# 15000/15000 [==============================] - 237s 16ms/step - loss: 6.3904e-08 - acc: 0.2759 - val_loss: 6.7620e-08 - val_acc: 0.2937
# Epoch 5/5
# 15000/15000 [==============================] - 236s 16ms/step - loss: 6.3904e-08 - acc: 0.2759 - val_loss: 6.7620e-08 - val_acc: 0.2937
# Test loss: 6.761965409077994e-08
# Test accuracy: 0.29372910380820355

# %%
print(X_train[1])
# Out:
# [[[ 5.4092979e+00]
#   [-2.3703299e+00]
#   [ 1.8132131e+00]
#   [-3.8214338e+00]
#   [ 2.5316554e-01]
#   [ 2.5251553e+00]
#   [-7.7073121e-01]
#   [ 7.5515592e-01]
#   [-9.8254657e-01]
#   [ 3.7979736e+00]
#   [-7.1492100e-01]
#   [-1.6236032e+00]
#   [ 4.5792632e+00]
#   [ 1.8694944e+00]
#   [-1.6817992e+00]
#   [ 9.5298082e-01]
#   [ 4.1191470e-02]
#   [ 1.7266220e-01]
#   [ 1.0281402e+00]
#   [-5.4344248e-02]
#   [ 1.7111796e+00]
#   [-7.3049372e-01]
#   [-1.5877988e+00]
#   [-2.4822676e+00]
#   [-6.2005781e-02]
#   [ 5.0790340e-01]
#   [-2.4492242e+00]
#   [-2.7459686e+00]]
#
#  [[ 3.3253353e+00]
#   [-2.7210140e-01]
#   [ 1.6172358e+00]
#   [-3.2827072e+00]
#   [ 2.4794462e-01]
#   [ 2.6016562e+00]
#   [-4.7557946e-02]
#   [ 2.6019776e-01]
#   [-3.8463056e-01]
#   [ 3.7481632e+00]
#   [-9.4382130e-02]
#   [-1.6279995e+00]
#   [ 2.4042540e+00]
#   [ 1.0522767e+00]
#   [ 6.9061883e-02]
#   [ 1.7473382e+00]
#   [ 3.2474890e-01]
#   [-6.8955672e-01]
#   [ 1.0852903e+00]
#   [ 3.6056656e-01]
#   [ 1.8731883e+00]
#   [-4.3915457e-01]
#   [ 6.9806784e-01]
#   [-1.8855525e+00]
#   [ 1.3633238e+00]
#   [ 1.2795942e+00]
#   [-2.9452605e+00]
#   [-1.1745116e+00]]
#
#  [[ 4.4201193e+00]
#   [-1.2745515e+00]
#   [ 1.0346932e+00]
#   [-3.8704906e+00]
#   [-5.0352633e-01]
#   [ 2.2075696e+00]
#   [-3.0729580e-01]
#   [ 1.3185666e+00]
#   [-1.0464766e+00]
#   [ 3.5385339e+00]
#   [-7.3739745e-02]
#   [-1.8180772e+00]
#   [ 2.5727985e+00]
#   [ 1.7199521e+00]
#   [ 9.6017879e-01]
#   [ 1.0952951e+00]
#   [ 5.7537442e-01]
#   [-2.5979459e-01]
#   [ 6.4498729e-01]
#   [-5.2467179e-01]
#   [ 1.6211690e+00]
#   [-7.7888656e-01]
#   [-8.7064318e-02]
#   [-2.1163619e+00]
#   [ 7.0065230e-01]
#   [ 2.7016217e-01]
#   [-2.5221517e+00]
#   [-1.3141197e+00]]
#
#  [[ 1.7239174e+00]
#   [-5.9516501e-01]
#   [ 3.8371074e-01]
#   [-1.3770863e+00]
#   [-6.1630584e-02]
#   [ 1.0570097e+00]
#   [-2.8036556e-01]
#   [ 2.7569532e-01]
#   [-3.7960139e-01]
#   [ 1.4426079e+00]
#   [ 1.0042349e-01]
#   [-7.1519780e-01]
#   [ 1.1664208e+00]
#   [ 5.5048913e-01]
#   [-3.1817207e-01]
#   [ 6.8448055e-01]
#   [ 4.8173688e-02]
#   [-1.8155038e-01]
#   [ 3.3581075e-01]
#   [-1.8400662e-02]
#   [ 4.7390386e-01]
#   [-5.5083460e-01]
#   [-5.5300720e-02]
#   [-9.5913023e-01]
#   [ 3.6409265e-01]
#   [ 1.2112695e-01]
#   [-1.4045599e+00]
#   [-8.7987781e-01]]
#
#  [[ 5.0868111e+00]
#   [-7.8005576e-01]
#   [ 1.3968627e+00]
#   [-4.6057453e+00]
#   [ 4.5341974e-01]
#   [ 2.9447720e+00]
#   [-1.1706769e+00]
#   [ 3.4922287e-01]
#   [-6.9561243e-01]
#   [ 3.8800595e+00]
#   [-1.1856824e+00]
#   [-2.6185567e+00]
#   [ 3.4076920e+00]
#   [ 1.7512736e+00]
#   [ 2.4937996e-01]
#   [ 9.7900176e-01]
#   [-3.2343125e-01]
#   [-9.0358192e-03]
#   [ 1.2822453e+00]
#   [ 9.2957282e-01]
#   [ 2.4405730e+00]
#   [-9.3900859e-01]
#   [ 1.8814541e-01]
#   [-3.4168084e+00]
#   [ 8.5430616e-01]
#   [ 7.9051638e-01]
#   [-3.3537192e+00]
#   [-2.3996804e+00]]
#
#  [[-1.0102451e-02]
#   [-1.0575611e-02]
#   [ 6.4892825e-03]
#   [-1.0560423e-02]
#   [-1.7239025e-02]
#   [-6.5919099e-04]
#   [ 7.9898359e-03]
#   [ 1.5100178e-03]
#   [-6.8800221e-03]
#   [-1.1400315e-02]
#   [-1.2464303e-02]
#   [ 1.1452178e-03]
#   [ 2.3338433e-02]
#   [ 2.3139582e-03]
#   [ 2.6241338e-02]
#   [-1.5214261e-02]
#   [ 7.8242123e-03]
#   [-1.6624194e-02]
#   [-4.8351719e-04]
#   [-5.8393772e-03]
#   [ 1.6126007e-02]
#   [ 4.4256262e-03]
#   [ 2.8847910e-03]
#   [ 3.7405491e-03]
#   [-1.5692306e-03]
#   [-1.5187125e-02]
#   [-3.9361692e-03]
#   [ 8.9599639e-03]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]
#
#  [[ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]
#   [ 0.0000000e+00]]]
